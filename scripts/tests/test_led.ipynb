# %%
import numpy as np
import matplotlib.pyplot as plt


import sys
sys.path.append('../../')
from scripts.neuralnetwork.led import LED

# %%
a = np.load('../../dataset/FN_test/FN_test_0.npz')
a
# Out:
# NpzFile '../../dataset/FN_test/FN_test_0.npz' with keys: data

# %%
l = LED(autoencoder_name='latdim10', rnn_name='rnn_smooth2', length_prediction=801)
l.get_data('../../dataset/FN_train/FN_train.npz', compressed_name='test_data')

# %%
l.run()

# %%
for j in [100*i+100 for i in range(9)]:
    # plt.subplot(221)
    # plt.imshow(l.decoded_future[j,:,:,0])
    # plt.subplot(223)
    # plt.imshow(l.data[j,:,:,0])
    # plt.subplot(222)
    # plt.imshow(l.decoded_future[j,:,:,1])
    # plt.subplot(224)
    # plt.imshow(l.data[j,:,:,1])


    fig, axes = plt.subplots(nrows=2, ncols=2)
    for i in [0,1]:
        im = axes[0,i].imshow(l.decoded_future[j,:,:,i])
        im = axes[1,i].imshow(l.data[j,:,:,i])

    fig.subplots_adjust(right=0.8)
    cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
    fig.colorbar(im, cax=cbar_ax)

    plt.show()

# %%
for i in range(10):
    plt.subplot(211)
    plt.plot(l.data[:,10,i,0])
    plt.plot(l.decoded_future[:,10,i,0])
    plt.subplot(212)
    plt.plot(l.data[:,10,i,1])
    plt.plot(l.decoded_future[:,10,i,1])
    plt.show()
