# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')
from scripts.NeuralNetwork.autoencoder import Autoencoder 
from scripts.utils.params import NNParams

import tensorflow as tf
tfk = tf.keras
tfkl = tfk.layers

# %%
ae = Autoencoder(latent_dim=40,input_shape=(20,20,2),conv=[(8,3),(16,3),(32,3)],dense=[32,64],activation='tanh')
ae.get_data()
ae.build_model()
ae.train_model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 ae = Autoencoder(latent_dim=40,input_shape=(20,20,2),conv=[(8,3),(16,3),(32,3)],dense=[32,64],activation='tanh')
#       2 ae.build_model()
# ----> 3 ae.train_model()
#
# File c:\Users\pc\PACSproject_AdaLED\scripts\NeuralNetwork\autoencoder.py:179, in Autoencoder.train_model(self)
#     178 def train_model(self):
# --> 179     history = self.autoencoder.fit(
#     180         self.data,
#     181         self.data,
#     182         batch_size=self.batch_size,
#     183         epochs=self.epochs,
#     184         validation_split=self.validation_split,
#     185         callbacks=self.callbacks,
#     186     ).history
#
# File c:\Users\pc\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\pc\anaconda3\lib\site-packages\keras\src\engine\data_adapter.py:1105, in select_data_adapter(x, y)
#    1102 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1103 if not adapter_cls:
#    1104     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1105     raise ValueError(
#    1106         "Failed to find data adapter that can handle input: {}, {}".format(
#    1107             _type_name(x), _type_name(y)
#    1108         )
#    1109     )
#    1110 elif len(adapter_cls) > 1:
#    1111     raise RuntimeError(
#    1112         "Data adapters should be mutually exclusive for "
#    1113         "handling inputs. Found multiple adapters {} to handle "
#    1114         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1115     )
#
# ValueError: Failed to find data adapter that can handle input: <class 'NoneType'>, <class 'NoneType'>

# %%
latent_dim = 40
data_dir_test = 'dataset/test_set.npz'

test = np.load(data_dir_test)['test_data']
print(np.shape(test[:30]))
# Out:
# (30, 1001, 20, 20, 2)

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(8, 6))

ax1.plot(np.arange(0,np.shape(test)[1],1), test[0, :, 2, 2, 0])
# ax1.set_xlabel('time [ms]')
ax1.set_ylabel('$u(t)$')
ax1.set_title('potential')

ax2.plot(np.arange(0,np.shape(test)[1],1), test[0, :, 2, 2, 1])
ax2.set_xlabel('time [ms]')
ax2.set_ylabel('$w(t)$')
ax2.set_title('recovery variable')

# %%
ae = Autoencoder(name='autoencoder5')

# %%
X_predicted, prediction_loss = ae.test_autoencoder(data_dir_test=data_dir_test,compressed_name_test='test_data')

# %%
prediction_loss = np.reshape(prediction_loss,(1,1001,20,20))
print(np.max(prediction_loss[0,:,:,:]))
# Out:
# 0.6172873079776764

# %%
plt.plot(np.arange(0,np.shape(test)[1],1),prediction_loss[0,:,0,0])

# %%
X_predicted = np.reshape(X_predicted,(1,1001,20,20,2))

for i in range(10):
    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(8, 6))

    ax1.plot(np.arange(0,np.shape(test)[1],1), X_predicted[0, :, i, i, 0])
    ax1.set_title('Predicted')

    ax2.plot(np.arange(0,np.shape(test)[1],1), test[0, :, i, i, 0])
    ax2.set_title('Test')

    plt.tight_layout()
    plt.show()

# %%
dataset = np.load('../../dataset/mitch_20.npz')
data = dataset['my_data']

print(np.shape(data))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14868\2289474782.py in <module>
# ----> 1 dataset = np.load('../../dataset/mitch_20.npz')
#       2 data = dataset['my_data']
#       3
#       4 print(np.shape(data))
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../dataset/mitch_20.npz'

# %%
latent_dim = 40
seq_length = 10
data_dir = "../../dataset/"
saving_dir = "../../models/"

Network = LED(latent_dim,data_dir,saving_dir)

# %%
input_shape_ae = np.shape(data)[-3:]
conv_ae = [(8,3),(16,3),(32,3)]
#conv_ae = [(16,3),(32,3)]
dense_ae = [75,128]
#dense_ae = [8]
Network.build_autoencoder(input_shape_ae, conv_ae, dense_ae)

# %%
callbacks =  [tfk.callbacks.EarlyStopping(
                    monitor='val_loss', patience=10, restore_best_weights=True),
                tfk.callbacks.ReduceLROnPlateau(
                    monitor='val_loss', patience=5, factor=0.5, min_lr=1e-5),
            ]
aeparams = NNParams(batch_size=32, epochs=1, validation_split=0.2, callbacks=callbacks)
#Network.train_autoencoder("mitch_20.npz",aeparams,"first_test")

# %%
input_shape_rnn = (seq_length,latent_dim)
dense_rnn = [64,32]
lstm_rnn = [(32,False),(16,True),(32,False)]

Network.build_RNN(input_shape_rnn, lstm_rnn, dense_rnn)

# %%
Network.train_RNN("mitch_20.npz", autoencoder_name="../../models/first_test", parameters=aeparams, saving_name="first_RNN_test")
