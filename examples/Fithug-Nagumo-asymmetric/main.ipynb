# %%
import sys
sys.path.append('../..')

import numpy as np
import matplotlib.pyplot as plt
from scripts.NeuralNetwork.led import LED

# %%
path_data = '../../dataset/FN_test_10/FN_test_10_0.npz'
ae_name = 'FN_asymmetric'
rnn_name = 'FN_rnn'
length_prediction = 300

led = LED(autoencoder_name=ae_name,
          rnn_name=rnn_name,
          length_prediction=length_prediction)

# %%
print(led.window_size)
# Out:
# 200

# %%
led.get_data(path_data,compressed_name='data')

# %%
led.run()

# %%
for i in range(5):
    plt.subplot(211)
    plt.plot(led.data[:,i,i,0])
    plt.plot(led.decoded_future[:,i,i,0])
    plt.subplot(212)
    plt.plot(led.data[:,i,i,1])
    plt.plot(led.decoded_future[:,i,i,1])
    plt.show()

# %%
ret = led.get_particle(x=2,y=1,plot=False)

# %%
prv = np.asarray(ret)

# plt.plot()

# %%
plt.plot(np.arange(0,400),prv[:,2,3,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.plot(np.arange(0,400),prv[:,2,3,0])
#
# IndexError: too many indices for array: array is 2-dimensional, but 4 were indexed
