# %%
import os
import sys
sys.path.append('../..')

import numpy as np
import matplotlib.pyplot as plt
from scripts.datagen.create_dataset import create_dataset
from scripts.utils.params import SolverParams,FNParams

# %%
# Instance a SolverParams object by reading the parameters from file
s_params = SolverParams.get_from_file('../../scripts/utils/parameters_files/parameters_FN.txt')

# Print the parameters 
s_params.print_params()

# Instance a FNParams object with the desired constants for the Fitzhug-Nagumo model
fn_params = FNParams(
    k=8, 
    alpha=0.15, 
    epsilon=1e-2, 
    I=0.125, 
    gamma=0.1, 
    grid_size=(20, 20)
)
# Out:
# Solver =  thetamethod
# T =  500.0
# dt =  0.5
# u0 =  [0, 0]
# Theta:  0.5
# Tolerance:  0.01

# %%
# Create the dataset for the Fitzhug-Nagumo model

# choose the name for your dataset
dataset_name = 'FN_test' 

# choose the number of samples and of processors. Further details inside the README.md file
create_dataset(
    dataset_name=dataset_name, 
    num_samples=1, 
    num_processes=1, 
    model_name='Fitzhug Nagumo',
    solver_params=s_params, 
    model_params=fn_params,
    generate=True, 
    remove_samples=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 7
#       4 dataset_name = 'FN_test'
#       6 # choose the number of samples and of processors. Further details inside the README.md file
# ----> 7 create_dataset(
#       8     dataset_name=dataset_name,
#       9     num_samples=1,
#      10     num_processes=1,
#      11     model_name='Fitzhug Nagumo',
#      12     solver_params=s_params,
#      13     model_params=fn_params,
#      14     generate=True,
#      15     remove_samples=True)
#
# File c:\Users\pc\PACSproject_AdaLED\examples\Fithug-Nagumo\../..\scripts\datagen\create_dataset.py:23, in create_dataset(dataset_name, num_samples, num_processes, model_name, solver_params, model_params, batch_size, generate, remove_samples)
#      19 if generate:
#      21     if model_name=='Fitzhug Nagumo':
# ---> 23         FN = FitzhugNagumo(
#      24             params=solver_params,
#      25             k=model_params.k,
#      26             alpha=model_params.alpha,
#      27             epsilon=model_params.epsilon,
#      28             I=model_params.I,
#      29             gamma=model_params.gamma,
#      30             grid_size=model_params.grid_size,
#      31         )
#      33         FN.generate_dataset(num_samples=num_samples, num_processes=num_processes)
#      35     if model_name == 'Van Der Pol':
#
# File c:\Users\pc\anaconda3\lib\functools.py:925, in singledispatchmethod.__get__.<locals>._method(*args, **kwargs)
#     924 def _method(*args, **kwargs):
# --> 925     method = self.dispatcher.dispatch(args[0].__class__)
#     926     return method.__get__(obj, cls)(*args, **kwargs)
#
# IndexError: tuple index out of range

# %%
# Plot the trend over time of the point (x,y) of the grid 

x = 2
y = 1
file_path = os.path.join("../../dataset", dataset_name, f"{dataset_name}_0.npz")
X = np.load(file_path)['data']

fig,(ax1,ax2) = plt.subplots(2,1,figsize=(8, 6))

ax1.plot(np.arange(0,np.shape(X)[1],1), X[0, :, x, y, 0])
ax1.set_title('x component')

ax2.plot(np.arange(0,np.shape(X)[1],1), X[0, :, x, y, 1])
ax2.set_title('y component')

plt.tight_layout()
plt.show()
