# %% [markdown]
# Here you can reproduce the results from the paper for the Fitzhug-Nagumo model

# %%
import sys
sys.path.append('../..')

import numpy as np
import matplotlib.pyplot as plt
from scripts.NeuralNetwork.led import LED

# %%
path_data = '../../dataset/FN_test/FN_test_0.npz'
ae_name = 'FN_autoencoder'
rnn_name = 'FN_rnn'
length_prediction = 200

led = LED(autoencoder_name=ae_name,
          rnn_name=rnn_name,
          length_prediction=length_prediction)

# %%
led.get_data(path_data,compressed_name='data')

# %%
led.run()

# %%
err = led.compute_error()
print(err)
# Out:
# [[1.89531046 1.99762112 2.36810608 2.54411302 2.3551287  2.05488409
#   2.46476375 2.62093618 3.04526921 2.96060736 3.22034166 3.26549424
#   2.83376723 3.10857433 3.11359673 3.70343359 3.6724472  3.84603744
#   3.88910044 3.80428305]
#  [2.05405394 2.94682028 2.49946131 1.87483122 1.99413379 2.08214001
#   2.40086021 2.11286124 2.23874218 1.60034922 1.23807722 1.08401693
#   1.03060401 1.11789936 1.2065471  1.97187715 2.69761472 3.43382946
#   3.39172963 3.65325128]
#  [3.23053149 2.2911828  1.09003872 1.6815292  2.05298556 1.88574389
#   1.11430535 1.90401923 2.79369411 3.29191505 3.58636559 3.91055201
#   3.78716631 3.6622481  2.85374321 2.30352831 1.7465563  0.92609834
#   1.84812499 2.99319941]
#  [2.02784398 1.03293268 1.26821521 1.37862498 1.02031289 1.89793427
#   3.52203488 4.15556538 4.49594339 5.02369909 5.07128085 5.41213038
#   5.24169833 5.18330082 4.99380204 4.56789907 4.04865459 3.15749185
#   2.37701212 0.95549352]
#  [1.23842182 1.16403585 1.15761968 0.99758715 2.60950634 3.83036096
#   4.53515697 5.0827319  5.4398283  5.98752526 6.4072048  6.66483391
#   6.81754358 6.67052281 6.3635413  5.77955365 5.14565602 4.34950586
#   3.61460768 2.53148209]
#  [1.2429899  1.3798441  0.98693772 3.01692624 4.10257484 4.89412605
#   5.59851528 6.23114697 6.94613935 7.4952291  7.65186408 7.71409649
#   7.55627751 7.48301302 7.54091171 7.17778207 6.58975907 5.84436738
#   4.93033237 3.77676442]
#  [1.55069826 1.11654377 2.79952477 4.05929273 4.92079611 5.82517501
#   6.71895419 7.56295068 7.50376763 7.05401516 5.46088082 4.27096341
#   3.48428434 3.15115596 3.91153174 4.30485596 6.05759061 6.89043192
#   6.21400879 5.04215868]
#  [1.49899136 2.10652338 3.88155186 4.4305205  5.83064889 6.93755835
#   7.64260186 7.44296813 5.39629615 3.64571791 4.30840873 3.9521482
#   4.22730444 4.40622568 4.21305217 3.25655731 2.18182949 4.07524243
#   6.4031646  6.34996582]
#  [0.67653232 3.07500054 4.43977544 5.43917296 6.8583189  7.46284487
#   6.54381997 4.85017402 3.9166969  3.31424583 2.81425179 3.026137
#   2.80519557 2.51592197 3.04429898 3.92634081 4.47543006 1.91980759
#   3.10747374 5.02132194]
#  [1.93728376 3.86516005 4.71415452 6.30425749 7.46010777 6.48227191
#   3.92265003 4.17417036 3.15126532 2.60804673 3.52479721 3.90431594
#   3.9195894  3.22630628 3.47740728 2.38531188 3.51939788 4.47496437
#   1.80776522 1.78701517]
#  [2.6577949  3.72263864 5.29411325 6.80065627 6.28792494 4.10526339
#   3.63546676 3.48998664 3.23309352 3.97392877 3.41806862 3.49509551
#   4.57651309 4.93779391 5.09617806 3.91921326 2.32380872 3.3118297
#   3.83075165 1.18156859]
#  [3.39047647 4.14739343 5.8064972  6.97966721 4.79572232 2.66308085
#   2.93754029 2.49687005 3.25136839 2.65275629 2.45489751 2.84347107
#   3.99218802 4.71103459 5.21670524 5.33652769 4.24807307 1.69461617
#   2.59120045 3.07315917]
#  [2.49990136 4.37037894 5.96842974 5.87336041 1.68593673 2.47816323
#   2.23989004 2.8369966  2.5301142  2.53400535 2.21424187 2.41600008
#   2.77857858 3.4627157  4.3734534  4.76106057 4.36135971 2.52861846
#   2.17184992 3.24147209]
#  [2.45216246 4.57593042 5.94071244 4.97136552 1.80650008 1.86579829
#   2.51846103 2.64151535 1.84184723 2.33737984 2.29315561 3.35357332
#   3.46960244 1.63067914 3.17226502 4.41562754 4.6960587  3.34652109
#   2.82370942 3.3946627 ]
#  [2.11119759 4.23154174 5.28976138 3.72145027 2.01889574 2.0349728
#   2.54715663 2.32764411 1.81703523 2.35491342 2.65282368 4.28106819
#   5.51149713 1.94734687 3.09505291 4.38866673 4.8465625  3.0868188
#   3.0631654  3.15355698]
#  [1.76203912 3.89185598 4.96884117 2.8896869  2.19996936 2.38908873
#   2.27782513 2.16827666 2.04115901 2.25532704 2.25343792 2.1494852
#   2.80939996 2.79126457 4.36406877 4.88149061 4.22065882 3.57230687
#   3.40430902 3.42283658]
#  [1.60646629 3.5644802  4.7216366  3.40300399 1.13486181 2.10994394
#   2.11641623 1.76214038 1.40465259 2.09588001 1.79642103 2.38731591
#   3.88504441 4.82738728 4.12851722 3.4877664  3.35776606 4.06487533
#   2.90758973 3.10874982]
#  [1.36903251 3.05581162 4.29481155 4.21000276 0.79533074 2.17234393
#   2.3379823  1.96795218 1.52815139 1.88515424 1.87405131 1.82214483
#   2.7338768  3.11083217 2.01543392 3.0440585  4.48653962 3.86647018
#   2.74312145 2.70784632]
#  [1.62903961 1.98503663 3.52331955 4.63310865 0.62700274 1.91673369
#   2.02737252 2.82908676 2.71432102 2.35730243 1.99991447 2.18535281
#   2.18339892 2.06826399 3.12033972 4.7812362  3.92014157 2.76465476
#   2.14232036 1.85072645]
#  [1.50380739 1.2752771  2.09727585 3.78246105 1.02696406 0.79387805
#   2.73638014 3.23813499 3.6585153  3.7679939  3.92446003 4.1550001
#   4.46154776 4.75232585 4.57837372 4.31039026 3.07288476 2.34020528
#   1.89053341 1.13260124]]

# %%
led.get_particle(x=2,y=1,plot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 led.get_particle(x=2,y=1,plot=True)
#
# File ~\OneDrive\Documenti\GitHub\PACSproject_AdaLED\examples\Fithug-Nagumo\../..\scripts\NeuralNetwork\led.py:95, in LED.get_particle(self, x, y, plot)
#      93 def get_particle(self,x,y,plot=False):
# ---> 95     particle = self.get_snapshot(times=np.arange(self.window_size,self.length_prediction))[:,x,y,:]
#      97     # If desired, plot the profile
#      98     if plot:
#
# TypeError: list indices must be integers or slices, not tuple
